# %% [markdown]
# <a href="https://colab.research.google.com/github/sofipop/MetodosNumericos/blob/Practica-1/IteracionPuntoFijo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import *
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
  return x**4-3*x**2-3

def g(x):
  return (3*x**2+3)**(1/4)

# %%
p0 = float(input("Ingrese el valor inicial p0:"))
tol = float(input("Ingrese el error: "))
N = int(input("Ingrese el número de iteraciones: "))
i = 0
error = 100
print("{:^5} {:^15} {:^15} {:^15} {:^15}".format("iter","p0","g(p0)", "f(p0)","error"))
while i <= N:

      p =g(p0)
      fp = f(p0)
      if abs(p - p0) < tol:
          print("El punto fijo es ",p,"despues de ",i,"iteraciones")
          break
      i = i + 1
      p0 = p
      error = abs(p-p0)
      e = error
      print("{:^5d} {:^15.6f} {:^15.6f} {:^15.10f} {:^15.5}".format(i, p0,p,fp,e))

if i >= N:
    print("Eror, el método no es valido")

x = np.linspace(1,2,101)
plt.plot(x,g(x))
plt.plot(x,f(x))
plt.title('punto fijo')
plt.grid()
plt.show()
# Out:
# Ingrese el valor inicial p0:0.3
# Ingrese el error: 4
# Ingrese el número de iteraciones: 3
# iter        p0             g(p0)           f(p0)           error
# El punto fijo es  1.3447357108378257 despues de  0 iteraciones
